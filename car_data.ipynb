# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as plt
import seaborn as sns
car_data=pd.read_csv("imports-85.csv")
df=pd.DataFrame(car_data)
print(df.head())

missing_data = df.isnull()
missing_data.head(5)

for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
    
car_data.plot(figsize=(12, 12))
plt.title(" Prices")
plt.xlabel("Name")
plt.ylabel("Price")
plt.show()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]
# 3
# False    204
# Name: 3, dtype: int64
#
# ?
# False    204
# Name: ?, dtype: int64
#
# alfa-romero
# False    204
# Name: alfa-romero, dtype: int64
#
# gas
# False    204
# Name: gas, dtype: int64
#
# std
# False    204
# Name: std, dtype: int64
#
# two
# False    204
# Name: two, dtype: int64
#
# convertible
# False    204
# Name: convertible, dtype: int64
#
# rwd
# False    204
# Name: rwd, dtype: int64
#
# front
# False    204
# Name: front, dtype: int64
#
# 88.60
# False    204
# Name: 88.60, dtype: int64
#
# 168.80
# False    204
# Name: 168.80, dtype: int64
#
# 64.10
# False    204
# Name: 64.10, dtype: int64
#
# 48.80
# False    204
# Name: 48.80, dtype: int64
#
# 2548
# False    204
# Name: 2548, dtype: int64
#
# dohc
# False    204
# Name: dohc, dtype: int64
#
# four
# False    204
# Name: four, dtype: int64
#
# 130
# False    204
# Name: 130, dtype: int64
#
# mpfi
# False    204
# Name: mpfi, dtype: int64
#
# 3.47
# False    204
# Name: 3.47, dtype: int64
#
# 2.68
# False    204
# Name: 2.68, dtype: int64
#
# 9.00
# False    204
# Name: 9.00, dtype: int64
#
# 111
# False    204
# Name: 111, dtype: int64
#
# 5000
# False    204
# Name: 5000, dtype: int64
#
# 21
# False    204
# Name: 21, dtype: int64
#
# 27
# False    204
# Name: 27, dtype: int64
#
# 13495
# False    204
# Name: 13495, dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 18
#      15     print("")
#      17 car_data.plot(figsize=(12, 12))
# ---> 18 plt.title(" Prices")
#      19 plt.xlabel("Name")
#      20 plt.ylabel("Price")
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\_api\__init__.py:224, in caching_module_getattr.<locals>.__getattr__(name)
#     222 if name in props:
#     223     return props[name].__get__(instance)
# --> 224 raise AttributeError(
#     225     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'title'
